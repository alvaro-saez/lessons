# %% [markdown]
# # Pandas Data Manipulation
#
# Some methods: `.isin()`, `sort_values()`, `.reset_index()`, `pd.merge()`, `pd.concat()`, `.set_index()`, `.get_dummies()`

# %%
import pandas as pd

# %%
df1 = pd.read_csv('./datasets/football_deaths.csv') # https://www.kaggle.com/shivamb/football-deaths
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 229 entries, 0 to 228
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   row_id                229 non-null    int64
#  1   incident_date         229 non-null    object
#  2   player_name           229 non-null    object
#  3   player_country        229 non-null    object
#  4   team_country          227 non-null    object
#  5   player_age            214 non-null    float64
#  6   player_team_name      229 non-null    object
#  7   incident_description  229 non-null    object
#  8   heart_related         229 non-null    int64
#  9   cardiac_related       229 non-null    int64
#  10  collapsed             229 non-null    int64
#  11  lightning             229 non-null    int64
#  12  collision             229 non-null    int64
# dtypes: float64(1), int64(6), object(6)
# memory usage: 23.4+ KB

# %%
print(df1.columns)
df1.head(1)
# Out:
# Index(['row_id', 'incident_date', 'player_name', 'player_country',
#        'team_country', 'player_age', 'player_team_name',
#        'incident_description', 'heart_related', 'cardiac_related', 'collapsed',
#        'lightning', 'collision'],
#       dtype='object')
#    row_id incident_date      player_name player_country team_country  \
# 0       1    1889-01-13  William Cropper        England      England
#
#    player_age player_team_name  \
# 0        26.0         Staveley
#
#                                 incident_description  heart_related  \
# 0  Ruptured bowel in a match against Grimsby Town...              0
#
#    cardiac_related  collapsed  lightning  collision
# 0                0          0          0          0

# %%
df1['player_country'].value_counts()
# Out:
# England                 29
# Nigeria                 18
# Brazil                  14
# Romania                  9
# Scotland                 9
#                         ..
# Zambia                   1
# Paraguay                 1
# Angola                   1
# United Arab Emirates     1
# Venezuela                1
# Name: player_country, Length: 82, dtype: int64

# %%
df1['player_team_name'].value_counts()
# Out:
# Retired                    2
# Dinamo București           2
# Cameroon                   2
# USON Mondeville            2
# Deportivo Cali             2
#                           ..
# Trinidad and Tobago U20    1
# Malaysia and Penang        1
# Benfica                    1
# CSD Municipal              1
# AS Saint Yves              1
# Name: player_team_name, Length: 222, dtype: int64

# %%
df1['incident_description'].value_counts()
# Out:
# Ruptured bowel in a match against Grimsby Town led to death the next day.                                                                                                                                                     1
# Collapsed on the field during his team's practice session in Bandung. He was rushed to the nearest hospital, but died on the way there. The cause of death was a heart attack.                                                1
# Suffered a heart attack in the th minute of a league match against General Lamadrid and died before reaching hospital.                                                                                                        1
# Cardiac arrest after seven minutes of the match between Tourizense and Carapinheirense.                                                                                                                                       1
# Cardiac arrest during a game in the Saughton Park in Edinburgh.                                                                                                                                                               1
#                                                                                                                                                                                                                              ..
# Sustained neck and spinal injuries in a collision with Landon Donovan during the  CONCACAF U- Tournament on  March . Paralysed, he died two years later on  March .                                                           1
# Collapsed while playing in the  FIFA Confederations Cup semi-final between his country and Colombia, and died shortly afterward in hospital. An autopsy later revealed the cause of death was hypertrophic cardiomyopathy.    1
# Suffered a heart attack and died on the field while playing in a charity football match in Singapore in .                                                                                                                     1
# Cardiac arrest caused by hypertrophic cardiomyopathy while playing against Vitória.                                                                                                                                           1
# Christophe Ramassamy, a -year-old footballer, suffered a fatal heart attack. Barely after  minutes of play, he collapsed on the pitch. The emergency services could do nothing to revive him.                                 1
# Name: incident_description, Length: 229, dtype: int64

# %%
df1_data = df1[['incident_date', 'player_country', 'player_age']]
df1_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 229 entries, 0 to 228
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   incident_date   229 non-null    object
#  1   player_country  229 non-null    object
#  2   player_age      214 non-null    float64
# dtypes: float64(1), object(2)
# memory usage: 5.5+ KB

# %%
df1_data['incident_date'] = df1_data['incident_date'].astype('datetime64[ns]')
#hay que hacer COLUMNA = COLUMNAxCAMBIO
df1_data.head()
df1_data.info()
#aunque te de el warning está funcionando
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 229 entries, 0 to 228
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   incident_date   229 non-null    datetime64[ns]
#  1   player_country  229 non-null    object
#  2   player_age      214 non-null    float64
# dtypes: datetime64[ns](1), float64(1), object(1)
# memory usage: 5.5+ KB
# C:\Users\AlvaroSaez\miniconda3\envs\ironhack\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
# We ike functions!!!
#.isin() = "if" --> es como un filtro, devuelve true y false en función de si coincide o no
def row_filter(df, cat_var, cat_values, sort_by):
    df = df[df[cat_var].isin(cat_values)].sort_values(by=sort_by, ascending=False)
    return df.reset_index(drop=True) #ponemos reset_index(drop=True) para que se cree un INDEX NUEVO
#si no ponemos reset_index el INDEX sería el antiguo (por loq ue estaría "desordenado")
# si ponemos reset_index(drop=False) te crea un nuevo ínidce y el antiguo te lo guarda en otra columna
#devuelve TODO el dataframe en el que el valor True está presente en la columna player_age

# %%
col = 'player_country'
var = ['Spain', 'France', 'Italy']
order = 'incident_date'

# %%
row_filter(df1_data, col, var, order)
# Out:
#    incident_date player_country  player_age
# 0     2021-10-15         France        54.0
# 1     2021-10-08         France        49.0
# 2     2021-06-01          Italy        29.0
# 3     2019-01-27          Spain        32.0
# 4     2018-09-14         France        26.0
# 5     2018-02-03          Spain        15.0
# 6     2016-03-13          Spain        28.0
# 7     2013-04-02         France        25.0
# 8     2012-04-14          Italy        25.0
# 9     2009-11-15          Italy        25.0
# 10    2009-08-08          Spain        26.0
# 11    2007-08-28          Spain        22.0
# 12    2001-11-20         France        26.0
# 13    1987-01-15          Spain        25.0
# 14    1980-04-21         France        24.0
# 15    1977-10-30          Italy        24.0
# 16    1973-01-07          Spain        27.0
# 17    1927-03-13         France        26.0

# %%
df
# no hemos creado el data_frame "df" ya que está dentro de la función, solo el return coniente lo que queremos
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\ALVARO~1\AppData\Local\Temp/ipykernel_5104/3998310793.py in <module>
# ----> 1 df
#       2 # no hemos creado el data_frame "df" ya que está dentro de la función, solo el return coniente lo que queremos
#
# NameError: name 'df' is not defined

# %%
#un ejemplo de lo que hace el .isin()
mask = df1['player_country'].isin(['Spain'])
mask
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 224    False
# 225    False
# 226    False
# 227    False
# 228    False
# Name: player_country, Length: 229, dtype: bool

# %% [markdown]
# ---

# %% [markdown]
# ### pd.merge()  & pd.concat() --> funciones
# df.join() & df.append() --> methods
#
# https://pandas.pydata.org/pandas-docs/stable/user_guide/merging.html

# %%
df_m1 = pd.DataFrame({'feature_key':['A','B','C'],'name':['Name 1','Name 2','Name 3']})
df_m1
# Out:
#   feature_key    name
# 0           A  Name 1
# 1           B  Name 2
# 2           C  Name 3

# %%
import random as r
feature_options = ['A','B','C']
value_random = [r.randint(1,5) for i in range(20)]
feature_random = [feature_options[r.randint(0,2)] for i in range(20)]

# %%
df_m2 = pd.DataFrame({'feature_key':feature_random,'value':value_random})
df_m2
# Out:
#    feature_key  value
# 0            A      5
# 1            C      5
# 2            C      5
# 3            B      2
# 4            C      2
# 5            B      1
# 6            B      1
# 7            A      5
# 8            C      2
# 9            B      3
# 10           A      1
# 11           C      5
# 12           B      5
# 13           A      3
# 14           A      4
# 15           C      3
# 16           C      5
# 17           B      3
# 18           B      4
# 19           C      2

# %%
# pd.merge() https://pandas.pydata.org/docs/reference/api/pandas.merge.html?highlight=merge#pandas.merge

df_m = pd.merge(df_m1, df_m2)
df_m
# Out:
#    feature_key    name  value
# 0            A  Name 1      5
# 1            A  Name 1      5
# 2            A  Name 1      1
# 3            A  Name 1      3
# 4            A  Name 1      4
# 5            B  Name 2      2
# 6            B  Name 2      1
# 7            B  Name 2      1
# 8            B  Name 2      3
# 9            B  Name 2      5
# 10           B  Name 2      3
# 11           B  Name 2      4
# 12           C  Name 3      5
# 13           C  Name 3      5
# 14           C  Name 3      2
# 15           C  Name 3      2
# 16           C  Name 3      5
# 17           C  Name 3      3
# 18           C  Name 3      5
# 19           C  Name 3      2

# %%
df_c1 = pd.DataFrame({'feature_key':feature_random,'value':value_random})
df_c1.head()
# Out:
#   feature_key  value
# 0           A      5
# 1           C      5
# 2           C      5
# 3           B      2
# 4           C      2

# %%
df_c2 = pd.DataFrame({'feature_key':feature_random,'value':value_random})
df_c2.head()
# Out:
#   feature_key  value
# 0           A      5
# 1           C      5
# 2           C      5
# 3           B      2
# 4           C      2

# %%
# pd.concat() https://pandas.pydata.org/docs/reference/api/pandas.concat.html

df_c = pd.concat([df_c1, df_c2]) #te AÑADE una tabla debajo de la otra
df_c
# Out:
#    feature_key  value
# 0            A      5
# 1            C      5
# 2            C      5
# 3            B      2
# 4            C      2
# 5            B      1
# 6            B      1
# 7            A      5
# 8            C      2
# 9            B      3
# 10           A      1
# 11           C      5
# 12           B      5
# 13           A      3
# 14           A      4
# 15           C      3
# 16           C      5
# 17           B      3
# 18           B      4
# 19           C      2
# 0            A      5
# 1            C      5
# 2            C      5
# 3            B      2
# 4            C      2
# 5            B      1
# 6            B      1
# 7            A      5
# 8            C      2
# 9            B      3
# 10           A      1
# 11           C      5
# 12           B      5
# 13           A      3
# 14           A      4
# 15           C      3
# 16           C      5
# 17           B      3
# 18           B      4
# 19           C      2

# %%
# .set_index() https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.set_index.html

df_c.set_index('feature_key', inplace=True)
df_c
# Out:
#              value
# feature_key
# A                5
# C                5
# C                5
# B                2
# C                2
# B                1
# B                1
# A                5
# C                2
# B                3
# A                1
# C                5
# B                5
# A                3
# A                4
# C                3
# C                5
# B                3
# B                4
# C                2
# A                5
# C                5
# C                5
# B                2
# C                2
# B                1
# B                1
# A                5
# C                2
# B                3
# A                1
# C                5
# B                5
# A                3
# A                4
# C                3
# C                5
# B                3
# B                4
# C                2

# %%
# pd.concat() https://pandas.pydata.org/docs/reference/api/pandas.concat.html

df_c = pd.concat([df_c1, df_c2], axis=1) #lo aplica sobre la coluumna
df_c
# Out:
#    feature_key  value feature_key  value
# 0            A      5           A      5
# 1            C      5           C      5
# 2            C      5           C      5
# 3            B      2           B      2
# 4            C      2           C      2
# 5            B      1           B      1
# 6            B      1           B      1
# 7            A      5           A      5
# 8            C      2           C      2
# 9            B      3           B      3
# 10           A      1           A      1
# 11           C      5           C      5
# 12           B      5           B      5
# 13           A      3           A      3
# 14           A      4           A      4
# 15           C      3           C      3
# 16           C      5           C      5
# 17           B      3           B      3
# 18           B      4           B      4
# 19           C      2           C      2

# %% [markdown]
# ---

# %% [markdown]
# __JOIN Types__ --> en el parámetro how=
#
# ![Image](./img/etl_pandas_manipulation_01.jpg)

# %% [markdown]
# ![Image](./img/etl_pandas_manipulation_02.jpg)

# %%
df_j1 = pd.DataFrame({'animal':['dog','cat','horse'],'breed':['pug','european','andalusian']})
df_j1
# Out:
#   animal       breed
# 0    dog         pug
# 1    cat    european
# 2  horse  andalusian

# %%
df_j2 = pd.DataFrame({'animal':['dog','cat','tardigrade'],'strength':[100, 200, 8000]})
df_j2
# Out:
#        animal  strength
# 0         dog       100
# 1         cat       200
# 2  tardigrade      8000

# %%
# Inner JOIN --> lo hace de forma determinada

df_ij = pd.merge(df_j1, df_j2)
df_ij
# Out:
#   animal     breed  strength
# 0    dog       pug       100
# 1    cat  european       200

# %%
# full Outer JOIN

df_oj = pd.merge(df_j1, df_j2, how='outer')
df_oj
# Out:
#        animal       breed  strength
# 0         dog         pug     100.0
# 1         cat    european     200.0
# 2       horse  andalusian       NaN
# 3  tardigrade         NaN    8000.0

# %%
# Left JOIN

df_lj = pd.merge(df_j1, df_j2, how='left')
df_lj
# Out:
#   animal       breed  strength
# 0    dog         pug     100.0
# 1    cat    european     200.0
# 2  horse  andalusian       NaN

# %%
# Right JOIN

df_rj = pd.merge(df_j1, df_j2, how='right')
df_rj
# Out:
#        animal     breed  strength
# 0         dog       pug       100
# 1         cat  european       200
# 2  tardigrade       NaN      8000

# %% [markdown]
# ---

# %% [markdown]
# ### pd.get_dummies()
#
# --> Convert categorical variable into dummy/indicator variables.
#
# (a.k.a. One-Hot-Encoding)
#
# https://pandas.pydata.org/docs/reference/api/pandas.get_dummies.html

# %%
df1.loc[df1['heart_related'] != 0,['player_name', 'heart_related', 'cardiac_related', 'collapsed', 'lightning', 'collision']]
# Out:
#                 player_name  heart_related  cardiac_related  collapsed  \
# 9    David "Soldier" Wilson              1                0          0
# 11             Frank Levick              1                0          0
# 29        Asbjørn Rønneberg              1                0          1
# 30                 Law Adam              1                0          0
# 36          Petar Radaković              1                0          1
# ..                      ...            ...              ...        ...
# 206      Ludwin Flores Nole              1                0          0
# 213            Ricky Yacobi              1                0          0
# 214              Sajjad Ali              1                0          0
# 219        Giuseppe Perrino              1                0          0
# 228    Christophe Ramassamy              1                0          1
#
#      lightning  collision
# 9            0          0
# 11           0          0
# 29           0          0
# 30           0          0
# 36           0          0
# ..         ...        ...
# 206          0          0
# 213          0          0
# 214          0          0
# 219          0          0
# 228          0          0
#
# [78 rows x 6 columns]

# %%
df_teams = df1.loc[df1['team_country'].isin(['England', 'Spain']) ,['player_name', 'team_country']]
df_dummies = pd.get_dummies(df_teams, columns=['team_country'])#, drop_first=True)
df_dummies
# Out:
#                 player_name  team_country_England  team_country_Spain
# 0           William Cropper                     1                   0
# 2         John Henry Morris                     1                   0
# 3          Walter Bannister                     1                   0
# 4               Teddy Smith                     1                   0
# 5               James Logan                     1                   0
# 6                Joe Powell                     1                   0
# 7             James Collins                     1                   0
# 8                  Di Jones                     1                   0
# 9    David "Soldier" Wilson                     1                   0
# 10         Tommy Blackstock                     1                   0
# 11             Frank Levick                     1                   0
# 13               Bob Benson                     1                   0
# 14         Horace Fairhurst                     1                   0
# 17               Tom Butler                     1                   0
# 20                Sam Wynne                     1                   0
# 24              Sim Raleigh                     1                   0
# 27             Jimmy Thorpe                     1                   0
# 37              Tony Allden                     1                   0
# 38           Pedro Berruezo                     0                   1
# 41             Tony Aveyard                     1                   0
# 48    José Antonio Gallardo                     0                   1
# 53          David Longhurst                     1                   0
# 87               Paul Sykes                     1                   0
# 94              Matt Gadsby                     1                   0
# 97               Anton Reid                     1                   0
# 98           Antonio Puerta                     0                   1
# 102              Hervé King                     1                   0
# 108           Daniel Jarque                     0                   1
# 121        Victor Omogbehin                     1                   0
# 154           Melissa Smith                     1                   0
# 157              Ben Hiscox                     1                   0
# 164             Junior Dian                     1                   0
# 169             Hugo Suárez                     0                   1
# 178           Dan Wilkinson                     1                   0
# 180           Jack Atkinson                     1                   0
# 182          James Moorfoot                     1                   0
# 185              Ben Walker                     1                   0
# 193           Nacho Barbera                     0                   1
# 203        Francisco Cavada                     0                   1
# 223              Dylan Rich                     1                   0

# %% [markdown]
# ---
